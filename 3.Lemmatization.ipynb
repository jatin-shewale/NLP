# %% [markdown]
# ## **Lemmatization**
#
# * Stemming      ----> Stem Words
# * Lemmatization ----> Root Word

# %%
## Q&A chatbots, text summrization

from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
'''
POS - Noun-n
Verb - v
adjective - a
adverb - r

'''

lemmatizer.lemmatize("going", pos = 'v')
# Out:
# 'go'

# %%
words = ["eating", "eats", "eaten", "writing", "writes", "programming", "programms", "history", "finally", "finalize"]

# %%
for word in words:
    print(word + " ----> " + lemmatizer.lemmatize(word))     # By default pos = 'n'
# Out:
# eating ----> eating
# eats ----> eats
# eaten ----> eaten
# writing ----> writing
# writes ----> writes
# programming ----> programming
# programms ----> programms
# history ----> history
# finally ----> finally
# finalize ----> finalize

# %%
for word in words:
    print(word + " ----> " + lemmatizer.lemmatize(word, pos = 'v'))
# Out:
# eating ----> eat
# eats ----> eat
# eaten ----> eat
# writing ----> write
# writes ----> write
# programming ----> program
# programms ----> programms
# history ----> history
# finally ----> finally
# finalize ----> finalize

# %%
lemmatizer.lemmatize("goes", pos = 'v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize("fairly", pos = 'v'), lemmatizer.lemmatize("sportingly", pos = 'v')
# Out:
# ('fairly', 'sportingly')
