# %%
sentence = "The Eiffel Tower was built from 1887 to 1889 by french Fnginnner Gustave Effiel, " \
"whose company specialized in building metalcframework and structure"

"""
Person Eg.: Jatin Shewale
Place or Location: India
Date Eg.: 06-06-2004
Time Eg.: 5:10 pm
Money Eg.: 1 Million DOllar
Organization Eg.: NA
Percent Eg.: NA
"""

# %%
sentence = "The Eiffel Tower was built from 1887 to 1889 by french Fnginnner Gustave Effiel, " \
"whose company specialized in building metalcframework and structure"

# %%
import nltk

words = nltk.word_tokenize(sentence)

# %%
tag_elements = nltk.pos_tag(words)

# %%
## Name Entity

nltk.ne_chunk(tag_elements).draw()
