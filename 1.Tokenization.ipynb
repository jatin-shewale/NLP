# %% [markdown]
# ### NLP Tokenization

# %%
corpus = """Hello Welcome, to the AI's ERA.
Master evry concept and beat the AI.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to the AI's ERA.
# Master evry concept and beat the AI.

# %%
## Tokenization
## Setence --> Paragrapgh

from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ["Hello Welcome, to the AI's ERA.", 'Master evry concept and beat the AI.']

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to the AI's ERA.
# Master evry concept and beat the AI.

# %%
## Tokenization
## Paragraph --> Words
## Sentence --> Words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'the',
#  'AI',
#  "'s",
#  'ERA',
#  '.',
#  'Master',
#  'evry',
#  'concept',
#  'and',
#  'beat',
#  'the',
#  'AI',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'the', 'AI', "'s", 'ERA', '.']
# ['Master', 'evry', 'concept', 'and', 'beat', 'the', 'AI', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'the',
#  'AI',
#  "'",
#  's',
#  'ERA',
#  '.',
#  'Master',
#  'evry',
#  'concept',
#  'and',
#  'beat',
#  'the',
#  'AI',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'the',
#  'AI',
#  "'s",
#  'ERA.',
#  'Master',
#  'evry',
#  'concept',
#  'and',
#  'beat',
#  'the',
#  'AI',
#  '.']
